# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd # primary data structure library
import folium

print('Folium installed and imported!')
# Out:
# Folium installed and imported!

# %%
df = pd.read_csv("area_codes (1).csv")
df.head()
# Out:
#    Code      Country
# 0   223         Mali
# 1   233        Ghana
# 2    31  Netherlands
# 3    32      Belgium
# 4    33       France

# %%
df.dtypes
# Out:
# Code        int64
# Country    object
# dtype: object

# %%
df_codes = pd.read_csv("world_country_and_usa_states_latitude_and_longitude_values.csv")
df.head()
# Out:
#   country_code   latitude  longitude               country usa_state_code  \
# 0           AD  42.546245   1.601554               Andorra             AK
# 1           AE  23.424076  53.847818  United Arab Emirates             AL
# 2           AF  33.939110  67.709953           Afghanistan             AR
# 3           AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4           AI  18.220554 -63.068615              Anguilla             CA
#
#    usa_state_latitude  usa_state_longitude   usa_state
# 0           63.588753          -154.493062      Alaska
# 1           32.318231           -86.902298     Alabama
# 2           35.201050           -91.831833    Arkansas
# 3           34.048928          -111.093731     Arizona
# 4           36.778261          -119.417932  California

# %%
df_area_codes = pd.read_csv("us-area-code-geo.csv")
df_area_codes.head()
# Out:
#    area_code   latitude   longitude
# 0        201  40.838850  -74.045678
# 1        202  38.895110  -77.036370
# 2        203  41.291798  -73.122453
# 3        205  33.427671  -86.886473
# 4        206  47.564027 -122.348976

# %%
df_ca_area_codes = pd.read_csv("ca-area-code-geo.csv")
df_ca_area_codes.head()
# Out:
#    area_code   latitude   longitude
# 0        204  51.203034  -98.729935
# 1        226  43.233831  -81.230922
# 2        236  50.432725 -121.515369
# 3        249  46.041823  -80.003286
# 4        250  50.837259 -121.841520

# %%
df_codes[['latitude', 'longitude']].loc[df_codes['country'] == 'United States']
# Out:
#      latitude  longitude
# 227  37.09024 -95.712891

# %%
def test(row):
  print(row)
  return pd.Series([row['Country'], row['Code']])

# %%
df2 = df.copy()
df2[['Country2', 'Code2']] = df2.apply(test, axis=1)
df2.head()

# %%
retval = df_area_codes[['latitude', 'longitude']].loc[df_area_codes['area_code'] == 647]
len(retval)
# Out:
# 0

# %%
def getLatitudeLongitude(row):
  if row['Country'] == 'United States':
    retVal = df_area_codes[['latitude', 'longitude']].loc[df_area_codes['area_code'] == row['Code']]
    if len(retVal) == 0:
      retVal = df_ca_area_codes[['latitude', 'longitude']].loc[df_ca_area_codes['area_code'] == row['Code']]
  else:
    retVal = df_codes[['latitude', 'longitude']].loc[df_codes['country'] == row['Country']]
  if len(retVal) == 1:
    return pd.Series([retVal.iloc[0, 0], retVal.iloc[0, 1]])
  return None

# %%
df.iloc[0]
# Out:
# Code        223
# Country    Mali
# Name: 0, dtype: object

# %%
ret = getLatitudeLongitude(df.iloc[0])
ret
#print("lat = ", lat, "; long = ", long)
# Out:
# 0    17.570692
# 1    -3.996166
# dtype: float64

# %%
df2 = df.copy()
df2[['latitude', 'longitude']] = df2.apply(getLatitudeLongitude, axis=1)
df2.head()
# Out:
#    Code      Country   latitude  longitude
# 0   223         Mali  17.570692  -3.996166
# 1   233        Ghana   7.946527  -1.023194
# 2    31  Netherlands  52.132633   5.291266
# 3    32      Belgium  50.503887   4.469936
# 4    33       France  46.227638   2.213749

# %%
df2[df2.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Code, Country, latitude, longitude]
# Index: []

# %%
df2.to_csv("chat_geo_data.csv", index=False)
